# %% [markdown]
# # Synthetic data (static barcoding)

# %% [markdown]
# We simulated a differentiation process over a bifurcation fork. In this simulation,
# cells are barcoded in the beginning, and the barcodes remain un-changed. In the simulation we resample clones over time, like the experimental design to obtain the hematopoietic dataset
# or the reprogramming dataset. The dataset has two time points.

# %%
import cospar as cs

# %% [markdown]
# ## Loading data

# %%
adata_orig = cs.datasets.synthetic_bifurcation_static_BC()
# Out:
#   0%|          | 0.00/1.48M [00:00<?, ?B/s]
# try downloading from url
# https://kleintools.hms.harvard.edu/tools/downloads/cospar/bifurcation_static_BC_adata_preprocessed.h5ad
# ... this may take a while but only happens once
# 100%|██████████| 1.48M/1.48M [00:00<00:00, 12.5MB/s]

# %%
adata_orig
# Out:
# AnnData object with n_obs × n_vars = 2474 × 50
#     obs: 'time_info', 'state_info'
#     uns: 'clonal_time_points', 'data_des'
#     obsm: 'X_clone', 'X_emb', 'X_pca'

# %%
cs.pl.embedding(adata_orig, color="state_info")

# %% [markdown]
# ## Raw clonal data analysis

# %%
cs.pl.clones_on_manifold(adata_orig, selected_clone_list=[1])

# %%
selected_time_point = "2"
cs.pl.fate_coupling_from_clones(adata_orig, selected_time_point, color_bar=True)

# %%
selected_time_point = "2"
cs.pl.barcode_heatmap(adata_orig, selected_time_point, color_bar=True)

# %%
clonal_fate_bias, clone_id = cs.pl.clonal_fate_bias(
    adata_orig, selected_fate="1", N_resampling=100
)
# Out:
# Current clone id: 0
# Current clone id: 50

# %% [markdown]
# ## Transition map inference

# %% [markdown]
# ### Transition map from multiple clonal time points.

# %%
noise_threshold = 0.2  #
selected_clonal_time_points = ["1", "2"]
adata = cs.tmap.infer_Tmap_from_multitime_clones(
    adata_orig,
    selected_clonal_time_points,
    smooth_array=[10, 10, 10],
    CoSpar_KNN=20,
    noise_threshold=noise_threshold,
)
# Out:
# -------Step 1: Select time points---------
# --> Clonal cell fraction (day 1-2): 1.0
# --> Clonal cell fraction (day 2-1): 1.0
# --> Numer of cells that are clonally related -- day 1: 854  and day 2: 1620
# Valid clone number 'FOR' post selection 52
# Cell number=2474, Clone number=52
# -------Step 2: Compute the full Similarity matrix if necessary---------
# Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.005406856536865234
# Smooth round: 2
# --> Time elapsed: 0.0331878662109375
# --> Orignal sparsity=0.18047254911058844, Thresholding
# --> Final sparsity=0.16805970451629854
# similarity matrix truncated (Smooth round=2):  0.06379485130310059
# Smooth round: 3
# --> Time elapsed: 0.16181492805480957
# --> Orignal sparsity=0.36128591024912937, Thresholding
# --> Final sparsity=0.3115755514586951
# similarity matrix truncated (Smooth round=3):  0.08571505546569824
# Smooth round: 4
# --> Time elapsed: 0.2683570384979248
# --> Orignal sparsity=0.4542983487444851, Thresholding
# --> Final sparsity=0.3801705890003
# similarity matrix truncated (Smooth round=4):  0.0779421329498291
# Smooth round: 5
# --> Time elapsed: 0.2640559673309326
# --> Orignal sparsity=0.5090226961858462, Thresholding
# --> Final sparsity=0.4313755539420809
# similarity matrix truncated (Smooth round=5):  0.08417201042175293
# Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 0.3234682083129883
# --> Orignal sparsity=0.5543067465096992, Thresholding
# --> Final sparsity=0.4738424317836788
# similarity matrix truncated (Smooth round=6):  0.08388614654541016
# Smooth round: 7
# --> Time elapsed: 0.3741140365600586
# --> Orignal sparsity=0.5961557187474064, Thresholding
# --> Final sparsity=0.5110177372564729
# similarity matrix truncated (Smooth round=7):  0.09585380554199219
# Smooth round: 8
# --> Time elapsed: 0.39272189140319824
# --> Orignal sparsity=0.6371680186959741, Thresholding
# --> Final sparsity=0.543228558414136
# similarity matrix truncated (Smooth round=8):  0.0972900390625
# Smooth round: 9
# --> Time elapsed: 0.4341130256652832
# --> Orignal sparsity=0.673204887826116, Thresholding
# --> Final sparsity=0.5714666157790415
# similarity matrix truncated (Smooth round=9):  0.09132909774780273
# Smooth round: 10
# --> Time elapsed: 0.44472193717956543
# --> Orignal sparsity=0.7017969910513152, Thresholding
# --> Final sparsity=0.5978522633774439
# similarity matrix truncated (Smooth round=10):  0.09817767143249512
# Save the matrix at every 5 rounds
# -------Step 3: Optimize the transition map recursively---------
# ---------Compute the transition map-----------
# Compute similarity matrix: load existing data
# --> Time elapsed:  0.014583826065063477
# --> Time elapsed:  0.02528214454650879
# --> Time elapsed:  0.009984016418457031
# --> Time elapsed:  0.025338172912597656
# Compute similarity matrix: load existing data
# --> Time elapsed:  0.014278888702392578
# --> Time elapsed:  0.027292251586914062
# --> Time elapsed:  0.008662939071655273
# --> Time elapsed:  0.03776192665100098
# Compute similarity matrix: load existing data
# --> Time elapsed:  0.008646965026855469
# --> Time elapsed:  0.02629709243774414
# --> Time elapsed:  0.011801004409790039
# --> Time elapsed:  0.03868985176086426
# Current iteration: 0
# Use smooth_round=10
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Start to smooth the refined clonal map
# Phase I: time elapsed --  0.03159785270690918
# Phase II: time elapsed --  0.04851198196411133
# Current iteration: 1
# Use smooth_round=10
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Start to smooth the refined clonal map
# Phase I: time elapsed --  0.01487421989440918
# Phase II: time elapsed --  0.035069942474365234
# Current iteration: 2
# Use smooth_round=10
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Start to smooth the refined clonal map
# Phase I: time elapsed --  0.01853799819946289
# Phase II: time elapsed --  0.03143119812011719
# No need for Final Smooth (i.e., clonally states are the final state space for Tmap)
# ----Demultiplexed transition map----
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# -----------Total used time: 17.9752037525177 s ------------

# %% [markdown]
# Generate demultiplexed map within each clone (Optional, as this map has been generated already)

# %%
run_demultiplex = False
if run_demultiplex:
    demulti_threshold = 0.2  # This threshold should be smaller, ass the map has been further smoothed to expand to more states.
    cs.tmap.infer_intraclone_Tmap(adata, demulti_threshold=demulti_threshold)

# %%
cs.pl.fate_bias_from_binary_competition(
    adata,
    selected_fates=["0", "1"],
    used_map_name="transition_map",
    plot_target_state=False,
    map_backwards=True,
    sum_fate_prob_thresh=0,
)

# %% [markdown]
# ### Transition map from a single clonal time point

# %%
initial_time_points = ["1"]
clonal_time_point = "2"
adata = cs.tmap.infer_Tmap_from_one_time_clones(
    adata_orig,
    initial_time_points,
    clonal_time_point,
    Clone_update_iter_N=1,
    initialize_method="OT",
    smooth_array=[10, 10, 10],
    noise_threshold=0.2,
    compute_new=False,
)
# Out:
# -------------------------------New Start--------------------------------------------------
# Current time point: 1
# -----------Pre-processing and sub-sampling cells------------
# ----------------
# Step 1: Use OT method for initialization
# Compute new shortest path distance matrix
# --> Chosen mode is distances
# Finishing computing shortest-path distance, used time 3.200489044189453
# Compute new custon OT matrix
# OT solver: duality_gap
# Finishing computing optial transport map, used time 3.3218679428100586
# ----------------
# Step 2: Jointly optimize the transition map and the initial clonal states!
# Joint optimization that consider possibility of clonal overlap: v2
# --> original clone shape: (2474, 52)
# --> After excluding zero-sized clones at t2: (2474, 52)
# Sort clones by size (small to large)
# Infer the number of initial cells to extract for each clone in advance
# --> Inferring early clonal states: current clone id 0
# ---------Compute the transition map-----------
# Compute similarity matrix: load existing data
# --> Time elapsed:  0.010777711868286133
# --> Time elapsed:  0.025355100631713867
# --> Time elapsed:  0.009119987487792969
# --> Time elapsed:  0.025571823120117188
# Compute similarity matrix: load existing data
# --> Time elapsed:  0.008907079696655273
# --> Time elapsed:  0.02606368064880371
# --> Time elapsed:  0.010649919509887695
# --> Time elapsed:  0.025574207305908203
# Compute similarity matrix: load existing data
# --> Time elapsed:  0.008044004440307617
# --> Time elapsed:  0.0219879150390625
# --> Time elapsed:  0.008307933807373047
# --> Time elapsed:  0.021279096603393555
# Current iteration: 0
# Use smooth_round=10
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Start to smooth the refined clonal map
# Phase I: time elapsed --  0.028378725051879883
# Phase II: time elapsed --  0.0417478084564209
# Current iteration: 1
# Use smooth_round=10
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Start to smooth the refined clonal map
# Phase I: time elapsed --  0.011940956115722656
# Phase II: time elapsed --  0.027230024337768555
# Current iteration: 2
# Use smooth_round=10
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Start to smooth the refined clonal map
# Phase I: time elapsed --  0.010509967803955078
# Phase II: time elapsed --  0.025044918060302734
# No need for Final Smooth (i.e., clonally states are the final state space for Tmap)
# ----Demultiplexed transition map----
# Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# Finishing computing transport map from CoSpar using inferred clonal data, used time 1.3011481761932373
# -----------Total used time: 7.911215305328369 s ------------

# %%
cs.pl.fate_bias_from_binary_competition(
    adata,
    selected_fates=["0", "1"],
    used_map_name="transition_map",
    plot_target_state=False,
    map_backwards=True,
    sum_fate_prob_thresh=0,
)

# %% [markdown]
# ### Transition amp from only the clonal information

# %%
cs.tmap.infer_Tmap_from_clonal_info_alone(adata)

cs.pl.fate_bias_from_binary_competition(
    adata,
    selected_fates=["0", "1"],
    used_map_name="clonal_transition_map",
    plot_target_state=False,
    map_backwards=True,
    sum_fate_prob_thresh=0,
)
